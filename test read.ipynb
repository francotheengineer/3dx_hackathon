# %%
import glymur

# %%
import cv2

# %%
import matplotlib.pyplot as plt

# %%
img = cv2.imread('/home/henrye/challenge/flood_images/DP_TALWOOD_AERIALPHOTO_2011_50CM/1016DP_TALWOOD_AERIALPHOTO_2011_50CM.jpg')

# %%
img= cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img)
plt.show()
# %matplotlib notebook
# Out:
# ...
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-8-78004a162373> in <module>()
#       1 plt.imshow(img)
#       2 plt.show()
# ----> 3 get_ipython().magic('matplotlib notebook')
#
# /home/henrye/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py in magic(self, arg_s)
#    2156         magic_name, _, magic_arg_s = arg_s.partition(' ')
#    2157         magic_name = magic_name.lstrip(prefilter.ESC_MAGIC)
# -> 2158         return self.run_line_magic(magic_name, magic_arg_s)
#    2159
#    2160     #-------------------------------------------------------------------------
#
# /home/henrye/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line)
#    2077                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2078             with self.builtin_trap:
# ...

# %%
print(img[:10,:10])
# Out:
# /home/henrye/anaconda3/lib/python3.6/site-packages/glymur/jp2k.py:1889: UserWarning: OpenJPEG library warning:  tgt_create tree->numnodes == 0, no tree created.
#   warnings.warn(msg, UserWarning)
# /home/henrye/anaconda3/lib/python3.6/site-packages/glymur/jp2k.py:1889: UserWarning: OpenJPEG library warning:  No incltree created.
#   warnings.warn(msg, UserWarning)
# /home/henrye/anaconda3/lib/python3.6/site-packages/glymur/jp2k.py:1889: UserWarning: OpenJPEG library warning:  No imsbtree created.
#   warnings.warn(msg, UserWarning)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-4d74cd21217a> in <module>()
# ----> 1 print(img[:10,:10])
#
# /home/henrye/anaconda3/lib/python3.6/site-packages/glymur/jp2k.py in __getitem__(self, pargs)
#    1072                 numcols if cols.stop is None else cols.stop
#    1073                 )
# ...

# %%
patch_width = 1024

w, h = img.shape[:2]
num_wide = w//patch_width

n = 33

j = n % num_wide
i = n//num_wide

patch = img[i*patch_width:(i+1)*patch_width, j*patch_width:(j+1)*patch_width]

fig, ax = plt.subplots(figsize=(10, 10))
ax.imshow(patch)
plt.show()

# %%
patch = img[10000-2000:10000+2000 ,5000-2000:5000+2000]

fig, ax = plt.subplots(figsize=(10, 10))
ax.imshow(patch)
plt.show()
